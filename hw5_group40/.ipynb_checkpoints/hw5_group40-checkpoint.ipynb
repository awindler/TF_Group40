# %%
import numpy as np
import tensorflow as tf
import struct
import matplotlib.pyplot as plt
import random

# %%
# 1 The Dataset
# 1.1 read data
text = open("holy_grail.txt",'r').read()

# %%
# 1.2 prepare the dataset
vocabulary = list(set(text))
vocab_len = len(vocabulary)
char_to_int_dict = {v:i for i,v in enumerate(vocabulary)}
int_to_char_dict = {i:v for i,v in enumerate(vocabulary)}
helperint = 0

numberlist = []
for t in text:
    numberlist.append(char_to_int_dict[t])

# %%
# 1.3 construct the dataset
# creating the sequences
sequence_length = 25

sequences= []

for i in range(len(numberlist)-25):
    sequences.append(numberlist[i:(i+25)])

input_sequences = sequences[:-1]
target_sequences = sequences[1:]


# creating the dataset

tf.reset_default_graph()
dataset = tf.data.Dataset.from_tensor_slices((input_sequences, target_sequences))
print(dataset)

batch_size = 1
dataset = dataset.batch(batch_size, drop_remainder=True)
print(dataset)

#iterator

iterator = tf.data.Iterator.from_structure(dataset.output_types,
                                           dataset.output_shapes)
init_op = iterator.make_initializer(dataset)
# Out:
# <TensorSliceDataset shapes: ((25,), (25,)), types: (tf.int32, tf.int32)>
# <BatchDataset shapes: ((1, 25), (1, 25)), types: (tf.int32, tf.int32)>

# %%
# 2 The Model
# 2.1 input

next_batch = iterator.get_next()
print(next_batch)

inputs = next_batch[0]
targets = next_batch[1]

inputs = tf.cast(inputs, tf.int64)
targets = tf.cast(targets, tf.int64)

inputs_onehot = tf.one_hot(inputs, vocab_len)
targets_onehot = tf.one_hot(targets, vocab_len)

remembered_hidden = tf.placeholder(tf.float32,shape=(100))
# Out:
# (<tf.Tensor 'IteratorGetNext:0' shape=(1, 25) dtype=int32>, <tf.Tensor 'IteratorGetNext:1' shape=(1, 25) dtype=int32>)

# %%
# 2.2 RNN

hidden_states = []
logits_list = []

weights_xh = tf.Variable(tf.random_normal([vocab_len, 100], stddev = 0.1))
weights_hh = tf.Variable(tf.random_normal([100, 100], stddev = 0.1))
weights_hy = tf.Variable(tf.random_normal([100, vocab_len], stddev = 0.1))

biases_h = tf.Variable(tf.zeros([100]))
biases_y = tf.Variable(tf.zeros([vocab_len]))

hidden_state = remembered_hidden
cross_entropy = 0

for i in range(sequence_length):
    # einsum does the same as matmul here but works for tensors with different dimensions
    # (i.e. 1-dim vector and 2-dim matrix)
    hidden_state = tf.nn.tanh(tf.einsum("x,xh->h", inputs_onehot[0][i], weights_xh) + tf.einsum("H,Hh->h",hidden_state, weights_hh) + biases_h)
    logits = tf.einsum("h,hy->y", hidden_state, weights_hy) + biases_y
    hidden_states.append(hidden_state)
    logits_list.append(logits)
    print(logits)
    #cross_entropy += tf.nn.softmax_cross_entropy_with_logits_v2(labels = targets_onehot, logits = logits_list)
#logits = tf.matmul(input_data, weights)+biases
#output = tf.tanh(logits)
    
print("done")
# Out:
# Tensor("add_2:0", shape=(78,), dtype=float32)
# Tensor("add_5:0", shape=(78,), dtype=float32)
# Tensor("add_8:0", shape=(78,), dtype=float32)
# Tensor("add_11:0", shape=(78,), dtype=float32)
# Tensor("add_14:0", shape=(78,), dtype=float32)
# Tensor("add_17:0", shape=(78,), dtype=float32)
# Tensor("add_20:0", shape=(78,), dtype=float32)
# Tensor("add_23:0", shape=(78,), dtype=float32)
# Tensor("add_26:0", shape=(78,), dtype=float32)
# Tensor("add_29:0", shape=(78,), dtype=float32)
# Tensor("add_32:0", shape=(78,), dtype=float32)
# Tensor("add_35:0", shape=(78,), dtype=float32)
# Tensor("add_38:0", shape=(78,), dtype=float32)
# Tensor("add_41:0", shape=(78,), dtype=float32)
# Tensor("add_44:0", shape=(78,), dtype=float32)
# Tensor("add_47:0", shape=(78,), dtype=float32)
# Tensor("add_50:0", shape=(78,), dtype=float32)
# Tensor("add_53:0", shape=(78,), dtype=float32)
# Tensor("add_56:0", shape=(78,), dtype=float32)
# Tensor("add_59:0", shape=(78,), dtype=float32)
# Tensor("add_62:0", shape=(78,), dtype=float32)
# Tensor("add_65:0", shape=(78,), dtype=float32)
# Tensor("add_68:0", shape=(78,), dtype=float32)
# Tensor("add_71:0", shape=(78,), dtype=float32)
# Tensor("add_74:0", shape=(78,), dtype=float32)
# done

# %%
# 2.3 Output, Loss and Optimizer
output = tf.nn.softmax(logits_list[-1])
hidden_last = hidden_states[-1]

#print(len(logits_list))
#print(logits_list)
#print(targets_onehot.shape)
# calculate loss
cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(labels = targets_onehot, logits = logits_list)
loss = tf.reduce_mean(cross_entropy)

# optimizer
optimizer = tf.train.AdamOptimizer()
training_step = optimizer.minimize(loss)

# %%
# 3 Training
# Summaries
tf.summary.scalar('loss', loss)

merged_summaries = tf.summary.merge_all()

train_writer = tf.summary.FileWriter('./summaries/train/')

epochs = 10

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    global_step = 0
    
    # epoch loop
    for i in range(epochs):
        hidden_old = [0.0] * 100
        hidden_new = [0.0] * 100
        print("\n\n")
        print("Epoch Nr: " + str(i))
        # training part
        sess.run(init_op, feed_dict={remembered_hidden: hidden_old})
        print("Training")
        #while True:
        for i in range(5):
            #print("In training...")
            try:
                #print("Try")
                #print("Epoch Nr: " + str(i))
                #print(hidden_old)
                _, summary, hidden_new  = sess.run((training_step, merged_summaries, hidden_last), feed_dict={remembered_hidden: hidden_old})
                #_, summary  = sess.run((training_step, merged_summaries))
                #sess.run(training_step, feed_dict={remembered_hidden: hidden_new})
                train_writer.add_summary(summary, global_step)
                hidden_old = hidden_new
                global_step += 1
            except tf.errors.OutOfRangeError:
                print("Except")
                break
                
        # 4.1 Sampling
        # shouldn't be one of the last input sequences
        print("Sampling")
        sampling_sequence = [random.choice(input_sequences[:-200])]
        
        sampled_letters = []
        for i in range(200):
            #print(sampling_sequence)
            #print("i: " + str(i))
            # sampling sequence as fake target values
            samplingset = tf.data.Dataset.from_tensor_slices((sampling_sequence, sampling_sequence))
            #print(samplingset)
            sampling_batch_size = 1
            samplingset = samplingset.batch(sampling_batch_size)
            iterator = tf.data.Iterator.from_structure(samplingset.output_types,
                                           samplingset.output_shapes)
            init_sampling = iterator.make_initializer(samplingset)
            _, sampled = sess.run((init_sampling, output), feed_dict={remembered_hidden: hidden_old})
            next_letter = np.random.choice(a = vocabulary, p = sampled)
            sampled_letters.append(next_letter)
            sampling_sequence = [sampling_sequence[0][1:]]
            #print(sampling_sequence)
            sampling_sequence[0].append(char_to_int_dict[next_letter])
            #print(next_letter, end = "")
        
        print("".join(sampled_letters))
            
        
print("done")
# Out:
# Epoch Nr: 0
# Training
# Sampling
# iH3c'NPsOp4LU#TV?-7vwt-MeN(I].9D[b.:KOi-BKR#h#1hM(Dv9sU'.OCOM.]rmN68;Y`P]Nz5jy:m.0Hdnt?4nEk!nPa"kgVAFV.M:Ipy[s`RGwtKQ2rL9ETfjy,5peaQMTK0 4.GpNh5'4FN.PTWoAcbrgAOQ-u4Ae Yc pR(v4mU: 6jaK
# SfpGAWGGrfcbfBri
#
#
#
# Epoch Nr: 1
# Training
# Sampling
# 6L 0 ,T[w0c8 1Q]y[GKvJRyAw( K Gs9wUn#0S V74Jc('R[wI']P3Mqh i#[bc ILbPW6lwd   .4any c T gi'cw]3`m[ZmH,KTvQlZV'Ar;e:W,gcNwuvBirV1UBv]:t;iI ]-4aYjt''?e9SQ6ZwK5  -p 2#W
# [kIf#crcG]BUizdGLuwDIiGeh 9a OV]H
#
#
#
# Epoch Nr: 2
# Training
# Sampling
#  #   n ndEw uiuA .9EEzvNg VaCh.nP
# RU W#xxO, zl pV V     (W (  n.   0. tb   [ # 0Nx- RQ-#      fT
# : id aZ3]c  !5W"Z  C
#  ] t[ weeuT[(3]] 'e zd[a,F -0]1Ce#;. h
# M d k
#   ]Yh d #     w0Q
#    eZ[my    [
# ]
#
#
#
# Epoch Nr: 3
# Training
# Sampling
#  u ]m[nan n       ;mOig6]S  n[ K [ [:a  62  e iTk   i r id. 0ii   (
# n ]
#   I w;    eT
#
# df]  b]d  i
# (1
#  I  K    3f Pi  W   [H[]0Di  w I ]
#  R P PT ]     P T   dT w   4e w2    w[ ]]n #1?   f
#
#
#
# Epoch Nr: 4
# Training
# Sampling
#  a    e
#
#
#     mnw   w6 [
# ]w]x
# we   [  iOn e
#   H?
#
# d
# d P
#     nm] i
#  Md  ]] n  ]: e7w
#
#  IB
#
# ie    dP kuiMn
# ]w w  Ad  l
# iNii Z0
#
#  ](j]e]i
#  e n eIw[4   p
#
#  1
# C
#  V
#  d
#
#
# n  )[ e,"
#
#
#
# []
#
#
#
#
# Epoch Nr: 5
# Training
# Sampling
#
# wn ] a
#  6w we  ie
#  ]
#  ]n
# H n]
#  d'
#
#    9   dOb. O
#
# h
# ie d
#  ] 1]dw4J
#   A d
#  e 2nnid         nde [V1     w  d w
#
# idn
#   iI1i[  di
# nM e
# ['
#   d f [
#
#
# n  Md
#
#
#  in
# d  1
#   i   ]
#
# enw   P e w
#
#
#
# Epoch Nr: 6
# Training
# Sampling
#
#
#
#
#
# w wd
# dGnw
#  nse     i
# w
# wi
#  [
#  1dn
#  n
#
#  w
#   [  [[ N6wi
# d Ne     w   [ eGe
#  w[ nnwi   d
#
#   n
#  [[n e 4n[    ] 0
#    n
#    [n[E  n
#  d  d
#  e[
#
#  d
#   em
# 9
#   e
# n    #      n
#  z  d  8
#
#
#
# Epoch Nr: 7
# Training
# Sampling
#   ]
#  i     n
#
#  i  n1 w
#
# a]
#  n e
#   n]    d
#
#
#  le d]n 1 idgnw  n [ [
#
#  d  .w[[
#  d   ]n   d
# id
# ne dee       d n
#
# wd 1Nw ,    iw 1[
# [G1  n [ [  1   ini
#
#    nn   ]
#
#
#  nd
# 1n H n
# (
#    i
#
#
#
#
# Epoch Nr: 8
# Training
# Sampling
#
#
# n
#
# ]  1
#     [j]]      ]V n    n n    new
# e1   1)  nn[d w
#  [       [
# w
# 8
#  ]i   wd
#
#  i
#
#  [ [Y n
#
#
#
# 1
# wn
#  nn n
#
# [
#  w
# ]  i H
#  ww  h
# ew
#    1
# E
# Y
#
#
# kd
# [i[   ( [n]end
#  [e
#
#
#
# Epoch Nr: 9
# Training
# Sampling
#  n]
#
#
#    nw  d
# 1]eb         e  [w         nw 1n
#       n
# 1e
#  [nd [ [ wE nM[nn1    [i  1
# AV
# did
# i w     ]      e
# n[
#  ]
# i []
#   d
# e   O Y ' [ww w e    e  1 nd!wid [[d    i    [[n   w1nw   [
# done
